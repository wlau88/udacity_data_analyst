# %% [markdown]
# #P3 Data Wrangling with MongoDB
#
# ###Map Area: San Francisco, CA

# %% [markdown]
# #0. Procedure
# ###Count types of tags in the dataset
#
# To get a rough sense of the data

# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json

# %%
def count_tags(filename):
        # YOUR CODE HERE
        tags = {}
        for event, elem in ET.iterparse(filename):
            if elem.tag not in tags.keys():
                tags[elem.tag] = 1
            else:
                tags[elem.tag] += 1
                
        return tags

# %%
print count_tags('san-francisco.osm')
# Out:
# {'node': 1410191, 'nd': 1677325, 'bounds': 1, 'member': 26246, 'tag': 949435, 'relation': 1687, 'way': 154315, 'osm': 1}

# %% [markdown]
# ###Count number of tag types

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        # YOUR CODE HERE
        key = element.get('k')
        if re.search(lower, key):
            keys['lower'] += 1
        elif re.search(lower_colon, key):
            keys['lower_colon'] += 1
        elif re.search(problemchars, key):
            keys['problemchars'] += 1
            if key not in keys['problemchars_dict']:
                keys['problemchars_dict'][key] = 1
            else: 
                keys['problemchars_dict'][key] += 1
        else:
            keys['other'] += 1
            if key not in keys['other_dict']:
                keys['other_dict'][key] = 1
            else: 
                keys['other_dict'][key] += 1
                
    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, 
            "problemchars_dict": {}, "other": 0,
            "other_dict": {}}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
tag_types_dict = process_map('san-francisco.osm')

# %%
print tag_types_dict
# Out:
# {'lower': 445870, 'other_dict': {'seamark:daymark:construction': 47, 'addr:street:source': 2, 'gnis:ST_num': 226, 'alt_name2': 1, 'seamark:buoy_special_purpose:status': 5, 'tiger:COUNTYFP': 1, 'seamark:fog_signal:group': 13, 'seamark:radar_transponder:category': 1, 'tiger:zip_right_3': 22, 'seamark:buoy_safe_water:colour': 1, 'tiger:zip_right_5': 1, 'tiger:zip_right_4': 7, 'seamark:daymark:source_date': 57, 'seamark:buoy_lateral:name': 7, 'tiger:zip_right_8': 1, 'service:bicycle:rental': 2, 'seamark:buoy_special_purpose:category': 6, 'tiger:zip_left_7': 1, 'tiger:zip_left_6': 1, 'tiger:zip_left_5': 1, 'tiger:zip_left_4': 16, 'tiger:zip_left_3': 50, 'seamark:platform:source': 1, 'tiger:zip_left_1': 642, 'seamark:daymark:shape': 57, 'seamark:buoy_lateral:system': 9, 'seamark:landmark:source_date': 1, 'parking:condition:both': 16, 'seamark:light:information': 1, 'seamark:beacon_special_purpose:status': 30, 'addr:1:housenumber': 1, 'seamark:fog_signal:sequence': 10, 'Building': 1, 'FG:area': 4, 'tiger:LINEARID': 7, 'NHS': 478, 'seamark:buoy_lateral:shape': 18, 'seamark:buoy_safe_water:colour_pattern': 1, 'seamark:light:1:height': 1, 'gosm:sig:8CBDE645': 7, 'seamark:platform:source_date': 1, 'gnis:County': 223, 'tiger:PLCIDFP': 85, 'seamark:beacon_lateral:status': 46, 'tiger:zip_right_1': 219, 'FIXME:bicycle': 4, 'seamark:light:1:colour': 1, 'seamark:light:sequence': 62, 'FG:perimeter': 4, 'FMMP_reviewed': 214, 'seamark:light:reference': 13, 'tiger:zip_right_2': 44, 'seamark:light:character': 66, 'parking:condition:right:2:reason': 26, 'note_2': 1, 'seamark:landmark:category': 3, 'parking:condition:both:maxstay': 14, 'seamark:daymark:information': 1, 'parking:condition:right:maxstay': 2, 'name_2': 166, 'scvwd:SHAPE_Area': 17, 'name_1': 1059, 'tiger:zip_right_7': 1, 'seamark:landmark:conspicuity': 1, 'FG:RTE': 4, '24h': 1, 'tiger:STATEFP': 85, 'AWATER': 353, 'Tiger:MTFCC': 360, 'seamark:beacon_special_purpose:reflectivity': 2, 'seamark:radar_transponder:group': 1, 'COUNTYFP': 351, 'seamark:light:visibility': 1, 'seamark:beacon_lateral:reflectivity': 8, 'parking:condition:left': 4, 'mtb:scale:uphill': 1, 'seamark:beacon_lateral:information': 7, 'MTFCC': 357, 'seamark:buoy_lateral:status': 7, 'seamark:beacon_special_purpose:shape': 30, 'seamark:buoy_lateral:source': 7, 'scvwd:SHAPE_AREA': 1, 'seamark:fog_signal:period': 14, 'tiger:FUNCSTAT': 83, 'seamark:light:1:sector_start': 1, 'seamark:fog_signal:information': 8, 'scvwd:OBJECTID': 18, 'seamark:light:group': 4, 'Tiger:HYDROID': 20, 'seamark:buoy_lateral:category': 17, 'seamark:fog_signal:generation': 11, 'Key': 1, 'seamark:light:height': 49, 'tiger:CLASSFP': 83, 'seamark:fog_signal:source_date': 16, 'tiger:name_type_1': 983, 'parking:condition:right:2': 26, 'seamark:light:source_date': 53, 'service:bicycle:repair': 16, 'seamark:beacon_lateral:category': 46, 'Nom': 3, 'seamark:beacon_lateral:colour': 46, 'seamark:buoy_special_purpose:colour': 7, 'seamark:buoy_lateral:colour': 17, 'tiger:RTTYP': 7, 'seamark:beacon_lateral:source': 46, 'seamark:fog_signal:status': 16, 'seamark:beacon_special_purpose:name': 16, 'seamark:buoy_special_purpose:source': 5, 'seamark:light:1:period': 1, 'tiger:zip_left_2': 118, 'CATEGORY': 2, 'parking:condition:right:time_interval': 2, 'tiger:PLACEFP': 85, 'LAND_ID': 2, 'FG:visitors': 4, 'parking:condition:both:residents': 14, 'NRHP': 11, 'seamark:buoy_special_purpose:shape': 8, 'seamark:beacon_special_purpose:source': 30, 'parking:condition:left:maxstay': 2, 'parking:condition:both:time_interval': 14, 'service:bicycle:retail': 16, 'tiger:PLACENS': 85, 'seamark:light:category': 2, 'scvwd:NAME': 17, 'gnis:County_num': 222, 'parking:lane:left': 7, 'seamark:light:1:character': 1, 'addr:housenumber:source': 3, 'parking:condition:left:2:reason': 26, 'CITY_OWNED': 2, 'parking:lane:both': 14, 'tiger:AWATER': 1, 'seamark:light:status': 8, 'parking:condition:left:2': 26, 'tiger:zip_left_8': 1, 'tiger:CPI': 84, 'seamark:buoy_safe_water:shape': 1, 'STATEFP': 351, 'FG:rt ...

# %%
print tag_types_dict['other_dict']

# most of them look like seamark (nautical chart standard), they can be ignored.
# Out:
# {'seamark:daymark:construction': 47, 'addr:street:source': 2, 'gnis:ST_num': 226, 'alt_name2': 1, 'seamark:buoy_special_purpose:status': 5, 'tiger:COUNTYFP': 1, 'seamark:fog_signal:group': 13, 'seamark:radar_transponder:category': 1, 'tiger:zip_right_3': 22, 'seamark:buoy_safe_water:colour': 1, 'tiger:zip_right_5': 1, 'tiger:zip_right_4': 7, 'seamark:daymark:source_date': 57, 'seamark:buoy_lateral:name': 7, 'tiger:zip_right_8': 1, 'service:bicycle:rental': 2, 'seamark:buoy_special_purpose:category': 6, 'tiger:zip_left_7': 1, 'tiger:zip_left_6': 1, 'tiger:zip_left_5': 1, 'tiger:zip_left_4': 16, 'tiger:zip_left_3': 50, 'seamark:platform:source': 1, 'tiger:zip_left_1': 642, 'seamark:daymark:shape': 57, 'seamark:buoy_lateral:system': 9, 'seamark:landmark:source_date': 1, 'parking:condition:both': 16, 'seamark:light:information': 1, 'seamark:beacon_special_purpose:status': 30, 'addr:1:housenumber': 1, 'seamark:fog_signal:sequence': 10, 'Building': 1, 'FG:area': 4, 'tiger:LINEARID': 7, 'NHS': 478, 'seamark:buoy_lateral:shape': 18, 'seamark:buoy_safe_water:colour_pattern': 1, 'seamark:light:1:height': 1, 'gosm:sig:8CBDE645': 7, 'seamark:platform:source_date': 1, 'gnis:County': 223, 'tiger:PLCIDFP': 85, 'seamark:beacon_lateral:status': 46, 'tiger:zip_right_1': 219, 'FIXME:bicycle': 4, 'seamark:light:1:colour': 1, 'seamark:light:sequence': 62, 'FG:perimeter': 4, 'FMMP_reviewed': 214, 'seamark:light:reference': 13, 'tiger:zip_right_2': 44, 'seamark:light:character': 66, 'parking:condition:right:2:reason': 26, 'note_2': 1, 'seamark:landmark:category': 3, 'parking:condition:both:maxstay': 14, 'seamark:daymark:information': 1, 'parking:condition:right:maxstay': 2, 'name_2': 166, 'scvwd:SHAPE_Area': 17, 'name_1': 1059, 'tiger:zip_right_7': 1, 'seamark:landmark:conspicuity': 1, 'FG:RTE': 4, '24h': 1, 'tiger:STATEFP': 85, 'AWATER': 353, 'Tiger:MTFCC': 360, 'seamark:beacon_special_purpose:reflectivity': 2, 'seamark:radar_transponder:group': 1, 'COUNTYFP': 351, 'seamark:light:visibility': 1, 'seamark:beacon_lateral:reflectivity': 8, 'parking:condition:left': 4, 'mtb:scale:uphill': 1, 'seamark:beacon_lateral:information': 7, 'MTFCC': 357, 'seamark:buoy_lateral:status': 7, 'seamark:beacon_special_purpose:shape': 30, 'seamark:buoy_lateral:source': 7, 'scvwd:SHAPE_AREA': 1, 'seamark:fog_signal:period': 14, 'tiger:FUNCSTAT': 83, 'seamark:light:1:sector_start': 1, 'seamark:fog_signal:information': 8, 'scvwd:OBJECTID': 18, 'seamark:light:group': 4, 'Tiger:HYDROID': 20, 'seamark:buoy_lateral:category': 17, 'seamark:fog_signal:generation': 11, 'Key': 1, 'seamark:light:height': 49, 'tiger:CLASSFP': 83, 'seamark:fog_signal:source_date': 16, 'tiger:name_type_1': 983, 'parking:condition:right:2': 26, 'seamark:light:source_date': 53, 'service:bicycle:repair': 16, 'seamark:beacon_lateral:category': 46, 'Nom': 3, 'seamark:beacon_lateral:colour': 46, 'seamark:buoy_special_purpose:colour': 7, 'seamark:buoy_lateral:colour': 17, 'tiger:RTTYP': 7, 'seamark:beacon_lateral:source': 46, 'seamark:fog_signal:status': 16, 'seamark:beacon_special_purpose:name': 16, 'seamark:buoy_special_purpose:source': 5, 'seamark:light:1:period': 1, 'tiger:zip_left_2': 118, 'CATEGORY': 2, 'parking:condition:right:time_interval': 2, 'tiger:PLACEFP': 85, 'LAND_ID': 2, 'FG:visitors': 4, 'parking:condition:both:residents': 14, 'NRHP': 11, 'seamark:buoy_special_purpose:shape': 8, 'seamark:beacon_special_purpose:source': 30, 'parking:condition:left:maxstay': 2, 'parking:condition:both:time_interval': 14, 'service:bicycle:retail': 16, 'tiger:PLACENS': 85, 'seamark:light:category': 2, 'scvwd:NAME': 17, 'gnis:County_num': 222, 'parking:lane:left': 7, 'seamark:light:1:character': 1, 'addr:housenumber:source': 3, 'parking:condition:left:2:reason': 26, 'CITY_OWNED': 2, 'parking:lane:both': 14, 'tiger:AWATER': 1, 'seamark:light:status': 8, 'parking:condition:left:2': 26, 'tiger:zip_left_8': 1, 'tiger:CPI': 84, 'seamark:buoy_safe_water:shape': 1, 'STATEFP': 351, 'FG:rte_description': 4, 'turn:lanes:b ...

# %%
print len(tag_types_dict['other_dict'])
# Out:
# 241

# %% [markdown]
# ###Auditing Postal codes and Street names

# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
            "Rd.": "Road",
            "Ave": "Avenue"
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def audit_postal_code(postal_codes, postal_code):
    if postal_code not in postal_codes:
        postal_codes.add(postal_code)
        print postal_code
        

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def is_postal_code(elem):
    return (elem.attrib['k'] == "addr:postcode")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    postal_codes = set()
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
#                 if is_street_name(tag):
#                     audit_street_type(street_types, tag.attrib['v'])
                    
                if is_postal_code(tag):
                    audit_postal_code(postal_codes, tag.attrib['v'])

#     return street_types
    return postal_codes

# %%
# postal codes audit
p_codes = audit('san-francisco.osm')
# Out:
# 94117
# 94102
# 94111
# 94710
# 94618
# 94611
# 94103
# 94704
# 94107
# 94002
# 94702
# 94703
# 94501
# 94709
# 94103-3124
# 94158
# 94115
# 94536
# 94706
# 94609
# 94556
# 94110
# 94132
# 94541
# 94124
# 94108
# 94131
# 94112
# 94121
# 94118
# 94123
# 94134
# 94114
# 94133
# 94116
# 94105
# 94122
# 94577
# 94804
# 94070
# 94109
# 94104
# 94030
# 94063
# 94607
# 94612
# 94612-2202
# 94904
# 94544
# 94404
# 94587
# 94213
# 94619
# 94602
# 94019
# 94080
# 94610
# 94608
# 94066
# 94939
# 94560
# 94555
# 94605
# 94403
# 94801
# 94014
# 94596
# 94549
# 94027
# 94061
# 94901
# 94065
# 94523
# 94606-3636
# 94606
# 94401
# 94502
# 94301
# 94925
# 94578
# 1087
# 94087
# 94705
# 94598
# 94113
# 90214
# 94707
# 94597
# 94920
# 93710
# CA
# 94601
# 94595
# 94530
# 94143
# 94062
# 94129
# 94188
# 94044
# 94805
# 94303
# 94127
# 94025
# CA 94133
# 94965
# 94002-3585
# 94402
# 94010
# CA 94030
# 94118-4504
# 94563
# CA:94103
# 94013
# 94015
# CA 94544
# 94579
# 94166
# 94545
# 94546
# 94519
# 94130
# 94941
# 94549-5506
# 94720-1076
# 515
# 94301-2019
# 94017
# 94621
# 94603
# 94117-9991
# 94115
# 94112
# 94121
# 94708
# 9412
# 94720
# 94613
# 95498
# 941234
# 94552

# %%
type(list(p_codes)[0])
# Out:
# str

# %% [markdown]
# ###Postal codes
#
# - whitespaces --> trim
# - CA --> truncate the front
# - extension --> truncate the back
# - 4 digit, 3 digit --> drop

# %%
for code in p_codes:
    if len(code) != 5:
        print '--------'
        print code
        print len(code)
        print ' '
# Out:
# --------
# CA 94544
# 8
#
# --------
# CA 94133
# 8
#
# --------
# CA:94103
# 8
#
# --------
# 94612-2202
# 10
#
# --------
# 94118-4504
# 10
#
# --------
# 1087
# 4
#
# --------
# 94720-1076
# 10
#
# --------
# CA 94030
# 8
#
# --------
# 94549-5506
# 10
#
# --------
# 9412
# 4
#
# --------
# 515
# 3
#
# --------
# 941234
# 6
#
# --------
# 94115
# 6
#
# --------
# 94606-3636
# 10
#
# --------
# 94301-2019
# 10
#
# --------
# 94112
# 6
#
# --------
# CA
# 2
#
# --------
# 94002-3585
# 10
#
# --------
# 94121
# 6
#
# --------
# 94103-3124
# 10
#
# --------
# 94117-9991
# 10

# %%
for code in p_codes:
    if len(code) != 5:
        print '--------'
        n_string = code.strip('CA:').strip()
        index = n_string.find('-')
        if index > 0:
            print n_string[0:index]
        elif len(n_string) != 5:
            print 'not 5', n_string
        else:
            print n_string
# Out:
# --------
# 94544
# --------
# 94133
# --------
# 94103
# --------
# 94612
# --------
# 94118
# --------
# not 5 1087
# --------
# 94720
# --------
# 94030
# --------
# 94549
# --------
# not 5 9412
# --------
# not 5 515
# --------
# not 5 941234
# --------
# 94115
# --------
# 94606
# --------
# 94301
# --------
# 94112
# --------
# not 5
# --------
# 94002
# --------
# 94121
# --------
# 94103
# --------
# 94117

# %%
def update_postal_code(code):
    if len(code) != 5:
        n_string = code.strip('CA:').strip()
        index = n_string.find('-')
        if index > 0:
            return n_string[0:index]
        elif len(n_string) != 5:
            return ''
        else:
            return n_string
    else:
        return code

# %% [markdown]
# ###Street types

# %%
st_types = audit('san-francisco.osm')

# %%
print sorted(st_types.keys())
# Out:
# ['1', '1.3', '120', '12180142', '15th', '170', '2', '24th', '3.2', '300', '4.5', '41276', '9th', 'A', 'Abenue', 'Academy', 'Alameda', 'Alcatraz', 'Alley', 'Arguello', 'Ave', 'Ave.', 'Bay', 'Bluxome', 'Blvd', 'Blvd,', 'Blvd.', 'Boulavard', 'Boulvard', 'Bradshaw', 'Brannan', 'Bridge', 'Bridgeway', 'Broadway', 'California', 'Center', 'Circle', 'Clement', 'Clemente', 'Columbus', 'Cortland', 'Cragmont', 'Cres', 'Crescent', 'Ct', 'Ctr', 'Cut', 'D', 'Dr', 'Dr.', 'E', 'East', 'Embarcadero', 'Everett', 'F', 'Fillmore', 'G', 'Geary', 'H', 'Harrison', 'Highway', 'Hwy', 'I-580', 'I-580)', 'Ic', 'Int', 'Judah', 'King', 'Las', 'Leimert', 'Leslie', 'Lindbergh', 'Ln', 'Ln.', 'Lugano', 'M', 'Mall', 'Market', 'Market/Castro', 'Market/Noe', 'Mission', 'Ness', 'North', 'Oakridge', 'Ora', 'Palms', 'Park', 'Path', 'Peak', 'Pl', 'Plaza', 'Plz', 'Post', 'Powell', 'Pulgas', 'Rd', 'Rd.', 'Real', 'Rhein', 'Rock', 'Schwerin', 'Sobrante', 'Southgate', 'Spencer', 'St', 'St.', 'Steet', 'Steps', 'Sutter', 'Telegraph', 'Terrace', 'Townsend', 'Valencia', 'View', 'Walk', 'Way', 'Wedemeyer', 'West', 'arrowhead', 'ave', 'avenue', 'broadway', 'bush', 'parkway', 'square', 'st', 'street', 'sutter']

# %% [markdown]
# ###Some invalid numeric street names
#
# - house number in the wrong place
# - 'PM'
#
# ###A's
#
# - Abenue
# - variants of avenue
#
# ###B's
#
# - variants of blvd and broadway
#
# ###C's
#
# - variants of crescent and court
#
# ###D's
#
# - variants of drive
#
# ###H's
#
# - variants of highway
#
# ###L's
#
# - variants of lanes and plaza
#
# ###R's
#
# - variants of road
#
# ###S's
#
# - variants of streets

# %%
for e in sorted(st_types.keys()):
    print e
    print '---------'
    print st_types[e]
    print ''
# Out:
# 1
# ---------
# set(['W Of Us 101 @ Jct Sr 1'])
#
# 1.3
# ---------
# set(['ALA 260 PM 1.3'])
#
# 120
# ---------
# set(['12th Street #120'])
#
# 12180142
# ---------
# set(['12180142'])
#
# 15th
# ---------
# set(['15th'])
#
# 170
# ---------
# set(['California Street, Suite 170'])
#
# 2
# ---------
# set(['San Francisco Bicycle Route 2'])
#
# 24th
# ---------
# set(['24th'])
#
# 3.2
# ---------
# set(['ALA 84 PM 3.2'])
#
# 300
# ---------
# set(['Mission Street #300'])
#
# 4.5
# ---------
# set(['SF 80 PM 4.5'])
#
# 41276
# ---------
# set(['Upton St 41276'])
#
# 9th
# ---------
# set(['9th'])
#
# A
# ---------
# set(['Avenue A', 'Upton St #A'])
#
# Abenue
# ---------
# set(['Columbus Abenue'])
#
# Academy
# ---------
# set(['California College Prep Academy'])
#
# Alameda
# ---------
# set(['Alameda', 'The Alameda'])
#
# Alcatraz
# ---------
# set(['Alcatraz'])
#
# Alley
# ---------
# set(["Kahn's Alley", 'Redfield Alley', 'Hodges Alley'])
#
# Arguello
# ---------
# set(['Arguello'])
#
# Ave
# ---------
# set(['Greenwood Ave', 'Earl Ave', 'West Portal Ave', 'Telegraph Ave', 'Grand Ave', 'University Ave', '45th Ave', 'W 25th Ave', 'Thorton Ave', '8th Ave', '7th Ave', 'Cherry Ave', 'Magnolia Ave', 'Floribunda Ave', 'Loma Vista Ave', 'Phelan Ave', 'Colusa Ave', 'Geneva Ave', 'Piedmont Ave', 'Corte Madera Ave', 'W & E Of Us 101 N Of Seminary Ave', 'Tehama Ave', 'San Pablo Ave', ' Grant Ave', 'Lorton Ave', 'Grant Ave', 'Cortland Ave', 'Allerton Ave', 'Pennsylvania Ave', 'Palmetto Ave', 'Hamilton Ave', 'Shattuck Ave', 'Day Ave', 'Van Ness Ave', 'Jerrold Ave', 'California Ave', 'Rand Ave'])
#
# Ave.
# ---------
# set(['Menalto Ave.', 'Jefferson Ave.', '960 Arlington Ave.', 'Hamilton Ave.', 'Fairmount Ave.', '7th Ave.', 'Grand Ave.', 'San Carlos Ave.', 'Edes Ave.', 'Cortland Ave.', 'Pennsylvania Ave.', 'Piedmont Ave.', 'Lincoln Ave.', 'Dartmouth Ave.'])
#
# Bay
# ---------
# set(['Bay'])
#
# Bluxome
# ---------
# set(['Bluxome'])
#
# Blvd
# ---------
# set(['International Blvd', 'Anza Blvd', 'Mission Blvd', 'Lewelling Blvd', '296 Airport Blvd', 'Airport Blvd', 'MacArthur Blvd', 'Monterey Blvd', 'Arguello Blvd', 'Fremont Blvd', 'Leimert Blvd', 'Skyline Blvd', 'Ardenwood Blvd', 'Cipriani Blvd', 'Park Blvd', 'Newark Blvd', 'Geary Blvd', '2501 East Bayshore Blvd', 'Monument Blvd', 'Junipero Serra & Westborough Blvd', 'Under Ramp Sw Quad Of Us 101 / Sr 92 Ic Off 19th Ave & Fashion Island Blvd', 'W MacArthur Blvd', '380 Foster City Blvd', '10500 Foothill Blvd', 'N California Blvd', '25555 Hesperian Blvd', '600 Leweling Blvd'])
#
# Blvd,
# ---------
# set(['Nw Quad I-280 / Sr 35 Ic @ Jct Hayne Rd, Golf Course Dr, Skyline Blvd,'])
#
# Blvd.
# ---------
# set(['Geary Blvd.', 'East Francisco Blvd.'])
#
# Boulavard
# ---------
# set(['Alemany Boulavard'])
#
# Boulvard
# ---------
# set(['Alemany Boulvard'])
#
# Bradshaw
# ---------
# set(['Bradshaw'])
#
# Brannan
# ---------
# set(['Brannan'])
#
# Bridge
# ---------
# set(['Pier 1  SM- Hayward Bridge'])
#
# Bridgeway
# ---------
# set(['Bridgeway'])
#
# Broadway
# ---------
# set(['Broadway', 'North Broadway'])
#
# California
# ---------
# set(['California'])
#
# Center
# ---------
# set(['County Center', 'Fort Mason Center', 'Bon Air Center', 'South Shore Center', 'Seramonte Center', 'Linda Mar Shopping Center'])
#
# Circle
# ---------
# set(['Inner Circle', 'Positano Circle', 'Harding Circle', 'Gloria Circle', 'The Circle', ' Camino Verde Circle', 'Holly Park Circle', 'Outer Circle', 'Wilson Circle', 'Blossom Circle', 'Columbia Circle'])
#
# Clement
# ---------
# set(['Clement'])
#
# Clemente
# ---------
# set(['San Clemente'])
#
# Columbus
# ---------
# set(['Columbus'])
#
# Cortland
# ---------
# set(['Cortland'])
#
# Cragmont
# ---------
# set(['Cragmont'])
#
# Cres
# ---------
# set(['Wellesley Cres'])
#
# Crescent
# ---------
# set(['Wellesley Crescent'])
#
# Ct
# ---------
# set(['Prescott Ct'])
#
# Ctr
# ---------
# set(['Tanforan Shopping Ctr'])
#
# Cut
# ---------
# set(['Short Cut'])
#
# D
# ---------
# set(['Avenue D'])
#
# Dr
# ---------
# set(['California Dr', 'Monte Verde Dr', 'Hillside Dr', 'Corriente Point Dr', 'Lakeside Dr', 'Chateau Dr'])
#
# Dr.
# ---------
# set(['Grandview Dr.'])
#
# E
# ---------
# set(['Avenue E'])
#
# East
# ---------
# set(['Buena Vista Avenue East'])
#
# Embarcadero
# ---------
# set(['Embarcadero', 'The Embarcadero'])
#
# Everett
# ---------
# set(['Everett'])
#
# F
# ---------
# set(['Avenue F'])
#
# Fillmore
# ---------
# set(['Fillmore'])
#
# G
# ---------
# set(['G'])
#
# Geary
# ---------
# set(['Geary'])
#
# H
# ---------
# set(['Avenue H'])
#
# Harrison
# ---------
# set(['Harrison'])
#
# Highway
# ---------
# set(['Panoramic Highway', 'Cabrillo Highway', 'Great Highway', 'North Cabrillo Highway', 'Eastshore Highway', 'Bayshore Highway', 'Shoreline Highway', 'Coast Highway'])
#
# Hwy
# ---------
# set(['Redwood Hwy', '40 Shoreline Hwy'])
#
# I-580
# ---------
# set(['E Of Center St @ I-580'])
#
# I-580)
# ---------
# set(['N Side Of Foothill Blvd @ John Dr (Near I-580)'])
#
# Ic
# ---------
# set(['Nw Quad Sr 84 / Ardenwood Blvd Ic', 'Ne Quad I-280 / Edgewood Rd Ic', 'Se Quad Sr 92 / Ralston Ic'])
#
# Int
# ---------
# set(['Se Quad Sr 1 / Crespi Dr Int', '012 Mi Ne Of Sr 1 / Linda Mar Blvd Int'])
#
# Judah
# ---------
# set(['Judah'])
#
# King
# ---------
# set(['King'])
#
# Las
# ---------
# set(['Alameda De Las'])
#
# Leimert
# ---------
# set(['Leimert'])
#
# Leslie
# ---------
# set(['Leslie'])
#
# Lindbergh
# ---------
# set(['Ne Quad Us 101 / 3rd Ave Off Lindbergh'])
#
# Ln
# ---------
# set(['Yerba Buena Ln'])
#
# Ln.
# ---------
# set(['Bont Ln.'])
#
# Lugano
# ---------
# set(['Via Lugano'])
#
# M
# ---------
# set(['Avenue M'])
#
# Mall
# ---------
# set(['Pacific Avenue Mall'])
#
# Market
# ---------
# set(['Market'])
#
# Market/Castro
# ---------
# set(['Market/Castro'])
#
# Market/Noe
# ---------
# set(['Market/Noe'])
#
# Mission
# ---------
# set(['Mission'])
#
# Ness
# ---------
# set(['Van Ness'])
#
# North
# ---------
# set(['Mission Bay Boulevard North'])
#
# Oakridge
# ---------
# set(['Oakridge'])
#
# Ora
# ---------
# set(['Avenue Del Ora'])
#
# Palms
# ---------
# set(['Avenue of the Palms'])
#
# Park
# ---------
# set(['South Park'])
#
# Path
# ---------
# set(['Indian Rock Path', 'Oak Street Path', 'Mendocino Path', 'Arden Path', 'Parnassus Path'])
#
# Peak
# ---------
# set(['Grizzly Peak'])
#
# Pl
# ---------
# set(['San Francisco/Oakland Bridge Toll Pl'])
#
# Plaza
# ---------
# set([' Willie Mays Plaza', 'Bay Bridge Toll Plaza', 'Willie Mays Plaza', 'Mint Plaza', 'Manor Plaza', 'SM-Hayward Br Toll Plaza', 'Frank H. Ogawa Plaza', 'Toll Plaza', 'Civic Center Plaza', 'Ferry Plaza', 'Lakeshore Plaza'])
#
# Plz
# ---------
# set(['Woodside Plz'])
#
# Post
# ---------
# set(['Post'])
#
# Powell
# ---------
# set(['Bay and Powell', 'Powell'])
#
# Pulgas
# ---------
# set(['Alameda de las Pulgas', 'Alameda de Las Pulgas', 'Alameda De Las Pulgas', 'Alamed de las Pulgas'])
#
# Rd
# ---------
# set(['Willow Rd', 'Se Quad I-680 / Rudgear Rd', 'Ascot Rd', 'Ygnacio Valley Rd', 'San Mateo Rd', 'Marshlands Rd', 'Rollins Rd'])
#
# Rd.
# ---------
# set(['Alpine Rd.'])
#
# Real
# ---------
# set(['El Camino Real', 'West El Camino Real', 'South el Camino Real', 'South El Camino Real'])
#
# Rhein
# ---------
# set(['Stein Am Rhein'])
#
# Rock
# ---------
# set(['Indian Rock'])
#
# Schwerin
# ---------
# set(['Schwerin'])
#
# Sobrante
# ---------
# set(['Camino Sobrante'])
#
# Southgate
# ---------
# set(['Southgate'])
#
# Spencer
# ---------
# set(['E & W Of  Us 101 @ Monte Mar & Spencer'])
#
# St
# ---------
# set(['Mendell St', 'Folsom St', 'Madison St', 'Fallon St', 'Jackson St', 'Valencia St', 'Pine St', 'Delancey St', 'Alice St', 'Kearny St', 'Polk St', 'Oak St', 'Washington St', 'Hollis St', 'Diamond St', 'Market St', 'Franklin St', 'Main St', 'Green St', 'Park St', 'Sutter St', 'Mission St', 'S Delaware St', '18th St', '6th St', 'Connecticut St', 'Union St', '2nd St', 'Laurel St', 'Missouri St', 'Church St', 'Sansome St', 'Adeline St', 'Hyde St', 'Brannan St', 'Fulton St', '8th St', 'Embarcadero St', '12th St', 'Fillmore St', 'Center St', 'Hayes St', 'Webster St', '19th St', 'Chester St', 'Peralta St', 'McAllister St', '31st Ave & Judah St', 'Clement St', 'Taraval St', 'San Pablo Av & Cedar St', 'Turk St', '4th St', 'Bryant St', 'Granada St', 'Under I-880 @ 7th St & Linden St', 'Williams St', '14th St', 'Post St', '16th St', ' Valencia St', 'Noe St', 'Under I-580 Btwn Fruitvale / Champion St', 'Howard St', ' Laguna St', '9th St', 'Cesar Chavez St St', 'Lyon St'])
#
# St.
# ---------
# set(['Market St.', 'Divisadero St.', 'Buchanan St.', 'California St.', 'Pine St.', 'Webster St.', 'Halleck St.', 'Jennings St.', 'Sutter St.', '9th St.', 'Fillmore St.', 'Fulton St.', 'Valencia St.', 'Haight St.'])
#
# Steet
# ---------
# set(['Guerrero Steet'])
#
# Steps
# ---------
# set(['Bancroft Steps'])
#
# Sutter
# ---------
# set(['Sutter'])
#
# Telegraph
# ---------
# set(['3605 Telegraph'])
#
# Terrace
# ---------
# set(['Eagle Hill Terrace', 'Peace Terrace', 'Broadway Terrace', 'Greenwood Terrace', 'Grenard Terrace', 'Bradshaw Terrace', 'Hawthorne Terrace'])
#
# Townsend
# ---------
# set(['Townsend'])
#
# Valencia
# ---------
# set(['Valencia'])
#
# View
# ---------
# set(['Norwood View'])
#
# Walk
# ---------
# set(['Rose Walk', 'Fountain Walk', 'Terrace Walk'])
#
# Way
# ---------
# set(['Devon Way', 'Piedmont Way', 'Darien Way', 'Hansen Way', 'Black Fox Way', 'Moraga Way', 'Harold Way', 'Kandle Way', 'Beach Head Way', 'Chemical Way', 'Dwight Way', 'Hillcrest Way', 'Whiting Way', 'Rocky Way', 'Sterling Way', 'Altamont Way', 'Convention Way', 'Hacker Way', 'Eastview Way', 'Juanita Way', 'Mayhew Way', 'Tum Suden Way', 'Industrial Way', 'Sanchez Way', 'West California Way', 'Woodland Way', 'Stoddard Way', 'Bret Harte Way', 'Dunsmuir Way', 'Sussex Way', 'Windsor Way', 'Cheshire Way', 'Mcnulty Way', 'Lakeview Way', 'Madison Way', 'Camberly Way', 'Lincoln Way', 'Boulevard Way', 'Cedarwood Way', 'California Way', 'Brandy Rock Way', 'Lancaster Way', 'Buckingham Way', '519 Nick Gust Way', 'Allston Way', 'Hanna Way', 'Crystal Way', 'Seminole Way', 'Claremont Way', 'Bancroft Way', 'Mohican Way', 'Chantel Way', 'Wessex Way', 'Bel Air Way', 'Panoramic Way', 'Masonic Way', 'Christopher Way', 'Berkeley Way', 'Arizona Way', 'Shattuck Av & Allston Way', 'Recreation Way', 'Bayridge Way', 'Chelsea Way', 'Glenn Way', 'Toyon Way', 'Spring Way', 'Muir Way', 'Shepard Way', 'Parkwood Way', 'Indian Way', 'Hamilton Way', 'Midfield Way', 'Embarcadero Way', 'Lakemead Way', 'Bristol Way', 'Tacoma Way', 'Buena Vista Way', 'Wilmington Way', 'Southview Way', 'Granger Way', 'Eastlake Way', 'Ludina Way', 'Martin Luther King Jr Way', 'Martin Luther King Way', 'Alston Way', 'Red Oak Way', 'Mills Way', 'Mitchell Way', 'Oakview Way', 'Laurel Way', 'Parkdale Way', 'Museum Way', 'Channing Way', 'Edgecliff Way', 'Cardinal Way', 'Cargo Way', 'Garden Way'])
#
# Wedemeyer
# ---------
# set(['Wedemeyer'])
#
# West
# ---------
# set(['Embarcadero West', 'Buena Vista Avenue West'])
#
# arrowhead
# ---------
# set(['lake arrowhead'])
#
# ave
# ---------
# set(['central ave'])
#
# avenue
# ---------
# set(['Santa Cruz avenue'])
#
# broadway
# ---------
# set(['broadway'])
#
# bush
# ---------
# set(['bush'])
#
# parkway
# ---------
# set(['Bridge parkway'])
#
# square
# ---------
# set(['33 union square'])
#
# st
# ---------
# set(['Crane st', '26th st'])
#
# street
# ---------
# set(['townsend street', 'market street', 'Vallejo street', 'laguna street', 'Woolsey street'])
#
# sutter
# ---------
# set(['sutter'])

# %% [markdown]
# ###Street types cleaning

# %%
# UPDATE THIS VARIABLE
mapping = { "Ave.": "Ave",
            "Abenue": "Ave",
            "ave": "Ave",
            "avenue": "Ave",
            "Blvd,": "Blvd",
            "Blvd.": "Blvd",
            "Boulavard": "Blvd",
            "Boulvard": "Blvd",
            "broadway": "Broadway",
            "bush": "Bush",
            "Cres": "Crescent",
            "Ctr": "Center",
            "Dr.": "Dr",
            "Hwy": "Highway",
            "Ln.": "Ln",
            "Plz": "Plaza",
            "parkway": "Parkway", 
            "Rd.": "Rd",
            "Steet": "St",
            "St.": "St",
            "st": "St",
            "street": "St",
            "square": "Square",
            "sutter": "Sutter" }


def update_street_name(name, mapping):

    # YOUR CODE HERE
    k = street_type_re.search(name)
    old = k.group()
    if old not in mapping.keys():
        return name
    else:
        new = mapping[old]
        return name.replace(old, new)


for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
# Out:
# Leimert => Leimert
# Willow Rd => Willow Rd
# Se Quad I-680 / Rudgear Rd => Se Quad I-680 / Rudgear Rd
# Ascot Rd => Ascot Rd
# Ygnacio Valley Rd => Ygnacio Valley Rd
# San Mateo Rd => San Mateo Rd
# Marshlands Rd => Marshlands Rd
# Rollins Rd => Rollins Rd
# broadway => Broadway
# Alameda => Alameda
# The Alameda => The Alameda
# Bay and Powell => Bay and Powell
# Powell => Powell
# Columbus Abenue => Columbus Ave
# bush => Bush
# Indian Rock Path => Indian Rock Path
# Oak Street Path => Oak Street Path
# Mendocino Path => Mendocino Path
# Arden Path => Arden Path
# Parnassus Path => Parnassus Path
# Oakridge => Oakridge
# E Of Center St @ I-580 => E Of Center St @ I-580
# San Clemente => San Clemente
# Avenue D => Avenue D
# Avenue H => Avenue H
# Bay => Bay
# 12th Street #120 => 12th Street #120
# Alemany Boulvard => Alemany Blvd
# Bancroft Steps => Bancroft Steps
# 24th => 24th
# Kahn's Alley => Kahn's Alley
# Redfield Alley => Redfield Alley
# Hodges Alley => Hodges Alley
# Market/Castro => Market/Castro
# Broadway => Broadway
# North Broadway => North Broadway
# Brannan => Brannan
# Embarcadero West => Embarcadero West
# Buena Vista Avenue West => Buena Vista Avenue West
# Wellesley Cres => Wellesley Crescent
# townsend street => townsend St
# market street => market St
# Vallejo street => Vallejo St
# laguna street => laguna St
# Woolsey street => Woolsey St
# ALA 84 PM 3.2 => ALA 84 PM 3.2
# Grandview Dr. => Grandview Dr
# Inner Circle => Inner Circle
# Positano Circle => Positano Circle
# Harding Circle => Harding Circle
# Gloria Circle => Gloria Circle
# The Circle => The Circle
#  Camino Verde Circle =>  Camino Verde Circle
# Holly Park Circle => Holly Park Circle
# Outer Circle => Outer Circle
# Wilson Circle => Wilson Circle
# Blossom Circle => Blossom Circle
# Columbia Circle => Columbia Circle
# Alpine Rd. => Alpine Rd
# San Francisco/Oakland Bridge Toll Pl => San Francisco/Oakland Bridge Toll Pl
# Avenue of the Palms => Avenue of the Palms
# Santa Cruz avenue => Santa Cruz Ave
# Everett => Everett
# South Park => South Park
# Woodside Plz => Woodside Plaza
# N Side Of Foothill Blvd @ John Dr (Near I-580) => N Side Of Foothill Blvd @ John Dr (Near I-580)
# 15th => 15th
# Avenue Del Ora => Avenue Del Ora
# King => King
# Menalto Ave. => Menalto Ave
# Jefferson Ave. => Jefferson Ave
# 960 Arlington Ave. => 960 Arlington Ave
# Hamilton Ave. => Hamilton Ave
# Fairmount Ave. => Fairmount Ave
# 7th Ave. => 7th Ave
# Grand Ave. => Grand Ave
# San Carlos Ave. => San Carlos Ave
# Edes Ave. => Edes Ave
# Cortland Ave. => Cortland Ave
# Pennsylvania Ave. => Pennsylvania Ave
# Piedmont Ave. => Piedmont Ave
# Lincoln Ave. => Lincoln Ave
# Dartmouth Ave. => Dartmouth Ave
# Harrison => Harrison
# G => G
# Mission Street #300 => Mission Street #300
#  Willie Mays Plaza =>  Willie Mays Plaza
# Bay Bridge Toll Plaza => Bay Bridge Toll Plaza
# Willie Mays Plaza => Willie Mays Plaza
# Mint Plaza => Mint Plaza
# Manor Plaza => Manor Plaza
# SM-Hayward Br Toll Plaza => SM-Hayward Br Toll Plaza
# Frank H. Ogawa Plaza => Frank H. Ogawa Plaza
# Toll Plaza => Toll Plaza
# Civic Center Plaza => Civic Center Plaza
# Ferry Plaza => Ferry Plaza
# Lakeshore Plaza => Lakeshore Plaza
# Sutter => Sutter
# Pacific Avenue Mall => Pacific Avenue Mall
# Indian Rock => Indian Rock
# Ne Quad Us 101 / 3rd Ave Off Lindbergh => Ne Quad Us 101 / 3rd Ave Off Lindbergh
# Nw Quad I-280 / Sr 35 Ic @ Jct Hayne Rd, Golf Course Dr, Skyline Blvd, => Nw Quad I-280 / Sr 35 Ic @ Jct Hayne Rd, Golf Course Dr, Skyline Blvd
# Geary Blvd. => Geary Blvd
# East Francisco Blvd. => East Francisco Blvd
# Bradshaw => Bradshaw
# Schwerin => Schwerin
# Via Lugano => Via Lugano
# Short Cut => Short Cut
# Bridgeway => Bridgeway
# Market St. => Market St
# Divisadero St. => Divisadero St
# Buchanan St. => Buchanan St
# California St. => California St
# Pine St. => Pine St
# Webster St. => Webster St
# Halleck St. => Halleck St
# Jennings St. => Jennings St
# Sutter St. => Sutter St
# 9th St. => 9th St
# Fillmore St. => Fillmore St
# Fulton St. => Fulton St
# Valencia St. => Valencia St
# Haight St. => Haight St
# Stein Am Rhein => Stein Am Rhein
# 33 union square => 33 union Square
# Alameda de las Pulgas => Alameda de las Pulgas
# Alameda de Las Pulgas => Alameda de Las Pulgas
# Alameda De Las Pulgas => Alameda De Las Pulgas
# Alamed de las Pulgas => Alamed de las Pulgas
# 3605 Telegraph => 3605 Telegraph
# Devon Way => Devon Way
# Piedmont Way => Piedmont Way
# Darien Way => Darien Way
# Hansen Way => Hansen Way
# Black Fox Way => Black Fox Way
# Moraga Way => Moraga Way
# Harold Way => Harold Way
# Kandle Way => Kandle Way
# Beach Head Way => Beach Head Way
# Chemical Way => Chemical Way
# Dwight Way => Dwight Way
# Hillcrest Way => Hillcrest Way
# Whiting Way => Whiting Way
# Rocky Way => Rocky Way
# Sterling Way => Sterling Way
# Altamont Way => Altamont Way
# Convention Way => Convention Way
# Hacker Way => Hacker Way
# Eastview Way => Eastview Way
# Juanita Way => Juanita Way
# Mayhew Way => Mayhew Way
# Tum Suden Way => Tum Suden Way
# Industrial Way => Industrial Way
# Sanchez Way => Sanchez Way
# West California Way => West California Way
# Woodland Way => Woodland Way
# Stoddard Way => Stoddard Way
# Bret Harte Way => Bret Harte Way
# Dunsmuir Way => Dunsmuir Way
# Sussex Way => Sussex Way
# Windsor Way => Windsor Way
# Cheshire Way => Cheshire Way
# Mcnulty Way => Mcnulty Way
# Lakeview Way => Lakeview Way
# Madison Way => Madison Way
# Camberly Way => Camberly Way
# Lincoln Way => Lincoln Way
# Boulevard Way => Boulevard Way
# Cedarwood Way => Cedarwood Way
# California Way => California Way
# Brandy Rock Way => Brandy Rock Way
# Lancaster Way => Lancaster Way
# Buckingham Way => Buckingham Way
# 519 Nick Gust Way => 519 Nick Gust Way
# Allston Way => Allston Way
# Hanna Way => Hanna Way
# Crystal Way => Crystal Way
# Seminole Way => Seminole Way
# Claremont Way => Claremont Way
# Bancroft Way => Bancroft Way
# Mohican Way => Mohican Way
# Chantel Way => Chantel Way
# Wessex Way => Wessex Way
# Bel Air Way => Bel Air Way
# Panoramic Way => Panoramic Way
# Masonic Way => Masonic Way
# Christopher Way => Christopher Way
# Berkeley Way => Berkeley Way
# Arizona Way => Arizona Way
# Shattuck Av & Allston Way => Shattuck Av & Allston Way
# Recreation Way => Recreation Way
# Bayridge Way => Bayridge Way
# Chelsea Way => Chelsea Way
# Glenn Way => Glenn Way
# Toyon Way => Toyon Way
# Spring Way => Spring Way
# Muir Way => Muir Way
# Shepard Way => Shepard Way
# Parkwood Way => Parkwood Way
# Indian Way => Indian Way
# Hamilton Way => Hamilton Way
# Midfield Way => Midfield Way
# Embarcadero Way => Embarcadero Way
# Lakemead Way => Lakemead Way
# Bristol Way => Bristol Way
# Tacoma Way => Tacoma Way
# Buena Vista Way => Buena Vista Way
# Wilmington Way => Wilmington Way
# Southview Way => Southview Way
# Granger Way => Granger Way
# Eastlake Way => Eastlake Way
# Ludina Way => Ludina Way
# Martin Luther King Jr Way => Martin Luther King Jr Way
# Martin Luther King Way => Martin Luther King Way
# Alston Way => Alston Way
# Red Oak Way => Red Oak Way
# Mills Way => Mills Way
# Mitchell Way => Mitchell Way
# Oakview Way => Oakview Way
# Laurel Way => Laurel Way
# Parkdale Way => Parkdale Way
# Museum Way => Museum Way
# Channing Way => Channing Way
# Edgecliff Way => Edgecliff Way
# Cardinal Way => Cardinal Way
# Cargo Way => Cargo Way
# Garden Way => Garden Way
# California Street, Suite 170 => California Street, Suite 170
# Columbus => Columbus
# Mission Bay Boulevard North => Mission Bay Boulevard North
# California College Prep Academy => California College Prep Academy
# Judah => Judah
# Van Ness => Van Ness
# E & W Of  Us 101 @ Monte Mar & Spencer => E & W Of  Us 101 @ Monte Mar & Spencer
# San Francisco Bicycle Route 2 => San Francisco Bicycle Route 2
# California => California
# Grizzly Peak => Grizzly Peak
# Wedemeyer => Wedemeyer
# Post => Post
# Cragmont => Cragmont
# County Center => County Center
# Fort Mason Center => Fort Mason Center
# Bon Air Center => Bon Air Center
# South Shore Center => South Shore Center
# Seramonte Center => Seramonte Center
# Linda Mar Shopping Center => Linda Mar Shopping Center
# Avenue F => Avenue F
# Arguello => Arguello
# Mendell St => Mendell St
# Folsom St => Folsom St
# Madison St => Madison St
# Fallon St => Fallon St
# Jackson St => Jackson St
# Valencia St => Valencia St
# Pine St => Pine St
# Delancey St => Delancey St
# Alice St => Alice St
# Kearny St => Kearny St
# Polk St => Polk St
# Oak St => Oak St
# Washington St => Washington St
# Hollis St => Hollis St
# Diamond St => Diamond St
# Market St => Market St
# Franklin St => Franklin St
# Main St => Main St
# Green St => Green St
# Park St => Park St
# Sutter St => Sutter St
# Mission St => Mission St
# S Delaware St => S Delaware St
# 18th St => 18th St
# 6th St => 6th St
# Connecticut St => Connecticut St
# Union St => Union St
# 2nd St => 2nd St
# Laurel St => Laurel St
# Missouri St => Missouri St
# Church St => Church St
# Sansome St => Sansome St
# Adeline St => Adeline St
# Hyde St => Hyde St
# Brannan St => Brannan St
# Fulton St => Fulton St
# 8th St => 8th St
# Embarcadero St => Embarcadero St
# 12th St => 12th St
# Fillmore St => Fillmore St
# Center St => Center St
# Hayes St => Hayes St
# Webster St => Webster St
# 19th St => 19th St
# Chester St => Chester St
# Peralta St => Peralta St
# McAllister St => McAllister St
# 31st Ave & Judah St => 31st Ave & Judah St
# Clement St => Clement St
# Taraval St => Taraval St
# San Pablo Av & Cedar St => San Pablo Av & Cedar St
# Turk St => Turk St
# 4th St => 4th St
# Bryant St => Bryant St
# Granada St => Granada St
# Under I-880 @ 7th St & Linden St => Under I-880 @ 7th St & Linden St
# Williams St => Williams St
# 14th St => 14th St
# Post St => Post St
# 16th St => 16th St
#  Valencia St =>  Valencia St
# Noe St => Noe St
# Under I-580 Btwn Fruitvale / Champion St => Under I-580 Btwn Fruitvale / Champion St
# Howard St => Howard St
#  Laguna St =>  Laguna St
# 9th St => 9th St
# Cesar Chavez St St => Cesar Chavez St St
# Lyon St => Lyon St
# Market/Noe => Market/Noe
# Guerrero Steet => Guerrero St
# Southgate => Southgate
# Geary => Geary
# Fillmore => Fillmore
# Se Quad Sr 1 / Crespi Dr Int => Se Quad Sr 1 / Crespi Dr Int
# 012 Mi Ne Of Sr 1 / Linda Mar Blvd Int => 012 Mi Ne Of Sr 1 / Linda Mar Blvd Int
# Rose Walk => Rose Walk
# Fountain Walk => Fountain Walk
# Terrace Walk => Terrace Walk
# Camino Sobrante => Camino Sobrante
# Clement => Clement
# 9th => 9th
# Greenwood Ave => Greenwood Ave
# Earl Ave => Earl Ave
# West Portal Ave => West Portal Ave
# Telegraph Ave => Telegraph Ave
# Grand Ave => Grand Ave
# University Ave => University Ave
# 45th Ave => 45th Ave
# W 25th Ave => W 25th Ave
# Thorton Ave => Thorton Ave
# 8th Ave => 8th Ave
# 7th Ave => 7th Ave
# Cherry Ave => Cherry Ave
# Magnolia Ave => Magnolia Ave
# Floribunda Ave => Floribunda Ave
# Loma Vista Ave => Loma Vista Ave
# Phelan Ave => Phelan Ave
# Colusa Ave => Colusa Ave
# Geneva Ave => Geneva Ave
# Piedmont Ave => Piedmont Ave
# Corte Madera Ave => Corte Madera Ave
# W & E Of Us 101 N Of Seminary Ave => W & E Of Us 101 N Of Seminary Ave
# Tehama Ave => Tehama Ave
# San Pablo Ave => San Pablo Ave
#  Grant Ave =>  Grant Ave
# Lorton Ave => Lorton Ave
# Grant Ave => Grant Ave
# Cortland Ave => Cortland Ave
# Allerton Ave => Allerton Ave
# Pennsylvania Ave => Pennsylvania Ave
# Palmetto Ave => Palmetto Ave
# Hamilton Ave => Hamilton Ave
# Shattuck Ave => Shattuck Ave
# Day Ave => Day Ave
# Van Ness Ave => Van Ness Ave
# Jerrold Ave => Jerrold Ave
# California Ave => California Ave
# Rand Ave => Rand Ave
# Bridge parkway => Bridge Parkway
# Market => Market
# Prescott Ct => Prescott Ct
# Alcatraz => Alcatraz
# ALA 260 PM 1.3 => ALA 260 PM 1.3
# Yerba Buena Ln => Yerba Buena Ln
# central ave => central Ave
# Valencia => Valencia
# Cortland => Cortland
# Panoramic Highway => Panoramic Highway
# Cabrillo Highway => Cabrillo Highway
# Great Highway => Great Highway
# North Cabrillo Highway => North Cabrillo Highway
# Eastshore Highway => Eastshore Highway
# Bayshore Highway => Bayshore Highway
# Shoreline Highway => Shoreline Highway
# Coast Highway => Coast Highway
# El Camino Real => El Camino Real
# West El Camino Real => West El Camino Real
# South el Camino Real => South el Camino Real
# South El Camino Real => South El Camino Real
# 12180142 => 12180142
# Buena Vista Avenue East => Buena Vista Avenue East
# lake arrowhead => lake arrowhead
# Embarcadero => Embarcadero
# The Embarcadero => The Embarcadero
# W Of Us 101 @ Jct Sr 1 => W Of Us 101 @ Jct Sr 1
# Townsend => Townsend
# Redwood Hwy => Redwood Highway
# 40 Shoreline Hwy => 40 Shoreline Highway
# California Dr => California Dr
# Monte Verde Dr => Monte Verde Dr
# Hillside Dr => Hillside Dr
# Corriente Point Dr => Corriente Point Dr
# Lakeside Dr => Lakeside Dr
# Chateau Dr => Chateau Dr
# Alameda De Las => Alameda De Las
# Avenue A => Avenue A
# Upton St #A => Upton St #A
# SF 80 PM 4.5 => SF 80 PM 4.5
# Bluxome => Bluxome
# Avenue E => Avenue E
# Tanforan Shopping Ctr => Tanforan Shopping Center
# Upton St 41276 => Upton St 41276
# Avenue M => Avenue M
# sutter => Sutter
# Bont Ln. => Bont Ln
# Alemany Boulavard => Alemany Blvd
# Norwood View => Norwood View
# Pier 1  SM- Hayward Bridge => Pier 1  SM- Hayward Bridge
# Mission => Mission
# Crane st => Crane St
# 26th st => 26th St
# Leslie => Leslie
# Eagle Hill Terrace => Eagle Hill Terrace
# Peace Terrace => Peace Terrace
# Broadway Terrace => Broadway Terrace
# Greenwood Terrace => Greenwood Terrace
# Grenard Terrace => Grenard Terrace
# Bradshaw Terrace => Bradshaw Terrace
# Hawthorne Terrace => Hawthorne Terrace
# International Blvd => International Blvd
# Anza Blvd => Anza Blvd
# Mission Blvd => Mission Blvd
# Lewelling Blvd => Lewelling Blvd
# 296 Airport Blvd => 296 Airport Blvd
# Airport Blvd => Airport Blvd
# MacArthur Blvd => MacArthur Blvd
# Monterey Blvd => Monterey Blvd
# Arguello Blvd => Arguello Blvd
# Fremont Blvd => Fremont Blvd
# Leimert Blvd => Leimert Blvd
# Skyline Blvd => Skyline Blvd
# Ardenwood Blvd => Ardenwood Blvd
# Cipriani Blvd => Cipriani Blvd
# Park Blvd => Park Blvd
# Newark Blvd => Newark Blvd
# Geary Blvd => Geary Blvd
# 2501 East Bayshore Blvd => 2501 East Bayshore Blvd
# Monument Blvd => Monument Blvd
# Junipero Serra & Westborough Blvd => Junipero Serra & Westborough Blvd
# Under Ramp Sw Quad Of Us 101 / Sr 92 Ic Off 19th Ave & Fashion Island Blvd => Under Ramp Sw Quad Of Us 101 / Sr 92 Ic Off 19th Ave & Fashion Island Blvd
# W MacArthur Blvd => W MacArthur Blvd
# 380 Foster City Blvd => 380 Foster City Blvd
# 10500 Foothill Blvd => 10500 Foothill Blvd
# N California Blvd => N California Blvd
# 25555 Hesperian Blvd => 25555 Hesperian Blvd
# 600 Leweling Blvd => 600 Leweling Blvd
# Nw Quad Sr 84 / Ardenwood Blvd Ic => Nw Quad Sr 84 / Ardenwood Blvd Ic
# Ne Quad I-280 / Edgewood Rd Ic => Ne Quad I-280 / Edgewood Rd Ic
# Se Quad Sr 92 / Ralston Ic => Se Quad Sr 92 / Ralston Ic
# Wellesley Crescent => Wellesley Crescent

# %% [markdown]
# ###Converting to JSON and preparing for MongoDB
#
# step is done with data_prep.py

# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
import pdb


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

# UPDATE THIS VARIABLE
mapping = { "Ave.": "Ave",
            "Abenue": "Ave",
            "ave": "Ave",
            "avenue": "Ave",
            "Avenue": "Ave",
            "Blvd,": "Blvd",
            "Blvd.": "Blvd",
            "Boulavard": "Blvd",
            "Boulvard": "Blvd",
            "Boulevard": "Blvd",
            "broadway": "Broadway",
            "bush": "Bush",
            "Cres": "Crescent",
            "Ctr": "Center",
            "Court": "Ct",
            "Dr.": "Dr",
            "Drive": "Dr",
            "Hwy": "Highway",
            "Ln.": "Ln",
            "Lane": "Ln",
            "Plz": "Plaza",
            "parkway": "Parkway", 
            "Rd.": "Rd",
            "Road": "Rd",
            "Steet": "St",
            "St.": "St",
            "st": "St",
            "street": "St",
            "Street": "St",
            "square": "Square",
            "sutter": "Sutter" }


def update_street_name(name, mapping):
    """
    converts a single entry of street name to the appropriate
    name
    INPUT: streetname, mapping
    OUTPUT: appropriate name
    """
    # YOUR CODE HERE
    try: # find the last word
        k = street_type_re.search(name)
        old = k.group()
        if old not in mapping.keys():
            print 'last word case'
            return name
        else:
            new = mapping[old]
            print 'last word case'
            return name.replace(old, new)
    except AttributeError: # if cannot find the last word
        return name
    

def update_postal_code(code):
    """
    converts a single entry of postal code to the appropriate
    postal code
    INPUT: postal code
    OUTPUT: appropriate postal code
    """
    if len(code) != 5:
        n_string = code.strip('CA:').strip()
        index = n_string.find('-')
        if index > 0:
            return n_string[0:index]
        elif len(n_string) != 5:
            return ''
        else:
            return n_string
    else:
        return code
    
    
def shape_element(element):
    node = {}
    node['created'] = {}
    node['address'] = {}
    node['node_refs'] = []
    node['pos'] = [0, 0]

    if element.tag == "node" or element.tag == "way" :
        for tag in element.iter():
            
            if tag.tag == 'tag': # if it is a secondary tag
                key = tag.get('k')
                if re.search(lower, key):
                    node[key] = tag.get('v')

                elif re.search(lower_colon, key):
                    if key[0:4] == 'addr':
                        if type(node['address']) != type({}): # not sure why it's not dict
                            node['address'] = {}
                        
                        if key[5:] == 'street': # if street case
                            print 'street case'
                            print update_street_name(tag.get('v'), mapping)
                            
                            node['address'][key[5:]] = update_street_name(tag.get('v'),
                                                                          mapping)
                            
                        elif key[5:] == 'postcode': # if postal code case
                            print 'postcode'
                            print update_postal_code(tag.get('v'))
                            
                            node['address'][key[5:]] = update_postal_code(tag.get('v'))
                            
                        else: # not street or postal case
                            node['address'][key[5:]] = tag.get('v')
                    
                    else:
                        node[key] = tag.get('v')

                elif re.search(problemchars, key):
                    print 'problematic', key
                else:
                    print 'else', key
            
            else:
                node['type'] = element.tag

                for k, v in tag.attrib.iteritems():
                    if k in CREATED:
                        node['created'][k] = v

                    elif k == 'lat':
                        node['pos'][0] = float(v)

                    elif k == 'lon':
                        node['pos'][1] = float(v)

                    elif k == 'user':
                        pass

                    elif k == 'ref' and element.tag == 'way':
                        node['node_refs'].append(v)

                    else: 
                        node[k] = v

        if node['address'] == {}:
            del node['address']
            
        if len(node['node_refs']) == 0:
            del node['node_refs']
        
#         print node
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
#         i = 0
        for _, element in ET.iterparse(file_in):
#             i += 1
#             if i == 1000000:
#                 pdb.set_trace()
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

# %% [markdown]
# ###Old working version

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
"""
Your task is to wrangle the data and transform the shape of the data
into the model we mentioned earlier. The output should be a list of dictionaries
that look like this:

{
"id": "2406124091",
"type: "node",
"visible":"true",
"created": {
          "version":"2",
          "changeset":"17206049",
          "timestamp":"2013-08-03T16:43:42Z",
          "user":"linuxUser16",
          "uid":"1219059"
        },
"pos": [41.9757030, -87.6921867],
"address": {
          "housenumber": "5157",
          "postcode": "60625",
          "street": "North Lincoln Ave"
        },
"amenity": "restaurant",
"cuisine": "mexican",
"name": "La Cabana De Don Luis",
"phone": "1 (773)-271-5176"
}

You have to complete the function 'shape_element'.
We have provided a function that will parse the map file, and call the function with the element
as an argument. You should return a dictionary, containing the shaped data for that element.
We have also provided a way to save the data in a file, so that you could use
mongoimport later on to import the shaped data into MongoDB. 

Note that in this exercise we do not use the 'update street name' procedures
you worked on in the previous exercise. If you are using this code in your final
project, you are strongly encouraged to use the code from previous exercise to 
update the street names before you save them to JSON. 

In particular the following things should be done:
- you should process only 2 types of top level tags: "node" and "way"
- all attributes of "node" and "way" should be turned into regular key/value pairs, except:
    - attributes in the CREATED array should be added under a key "created"
    - attributes for latitude and longitude should be added to a "pos" array,
      for use in geospacial indexing. Make sure the values inside "pos" array are floats
      and not strings. 
- if second level tag "k" value contains problematic characters, it should be ignored
- if second level tag "k" value starts with "addr:", it should be added to a dictionary "address"
- if second level tag "k" value does not start with "addr:", but contains ":", you can process it
  same as any other tag.
- if there is a second ":" that separates the type/direction of a street,
  the tag should be ignored, for example:

<tag k="addr:housenumber" v="5158"/>
<tag k="addr:street" v="North Lincoln Avenue"/>
<tag k="addr:street:name" v="Lincoln"/>
<tag k="addr:street:prefix" v="North"/>
<tag k="addr:street:type" v="Avenue"/>
<tag k="amenity" v="pharmacy"/>

  should be turned into:

{...
"address": {
    "housenumber": 5158,
    "street": "North Lincoln Avenue"
}
"amenity": "pharmacy",
...
}

- for "way" specifically:

  <nd ref="305896090"/>
  <nd ref="1719825889"/>

should be turned into
"node_refs": ["305896090", "1719825889"]
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    print 11111
    print element
    print 22222
    node['created'] = {}
    node['address'] = {}
    node['node_refs'] = []
    node['pos'] = [0, 0]
    if element.tag == "node" or element.tag == "way" :
        # YOUR CODE HERE
        for tag in element.iter():
            print 22333
            print tag.attrib
            # cut from here start 
            try:
                key = tag.get('k')
                if re.search(lower, key):
                    print 'lower', key, tag.get('v')
                    node[key] = tag.get('v')
                    print node
                elif re.search(lower_colon, key):
                    print 'lower colon', key, tag.get('v')
                    if key[0:4] == 'addr':
                        node['address'][key[5:]] = tag.get('v')
                    else:
                        node[key] = tag.get('v')
                    print node
                elif re.search(problemchars, key):
                    print 'problematic', key
                else:
                    print 'else', key
                print 23333
            except:
                pass
            # cut from here end
            node['type'] = element.tag
            for k, v in tag.attrib.iteritems():
                if k in CREATED:
                    node['created'][k] = v
                    
                elif k == 'lat':
                    node['pos'][0] = float(v)
                    
                elif k == 'lon':
                    node['pos'][1] = float(v)
                    
                elif k == 'user':
                    pass
                
                elif k == 'ref' and element.tag == 'way':
                    node['node_refs'].append(v)
                
                else: 
                    print 33331
                    
                    node[k] = v
                    #print node
                    #print 33332
                
        print 33333
        print node
        print 44444
        if node['address'] == {}:
            del node['address']
            
        if len(node['node_refs']) == 0:
            del node['node_refs']
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

def test():
    # NOTE: if you are running this code on your computer, with a larger dataset, 
    # call the process_map procedure with pretty=False. The pretty=True option adds 
    # additional spaces to the output, making it significantly larger.
    data = process_map('example.osm', True)
    #pprint.pprint(data)
    
    print 'TEST'
    print data[0]
    
    correct_first_elem = {
        "id": "261114295", 
        "visible": "true", 
        "type": "node", 
        "pos": [41.9730791, -87.6866303], 
        "created": {
            "changeset": "11129782", 
            "user": "bbmiller", 
            "version": "7", 
            "uid": "451048", 
            "timestamp": "2012-03-28T18:31:23Z"
        }
    }
    assert data[0] == correct_first_elem
    
    print 'TEST'
    print data[-1]
    assert data[-1]["address"] == {
                                    "street": "West Lexington St.", 
                                    "housenumber": "1412"
                                      }
    assert data[-1]["node_refs"] == [ "2199822281", "2199822390",  "2199822392", "2199822369", 
                                    "2199822370", "2199822284", "2199822281"]

if __name__ == "__main__":
    test()

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
"""
Your task is to wrangle the data and transform the shape of the data
into the model we mentioned earlier. The output should be a list of dictionaries
that look like this:

{
"id": "2406124091",
"type: "node",
"visible":"true",
"created": {
          "version":"2",
          "changeset":"17206049",
          "timestamp":"2013-08-03T16:43:42Z",
          "user":"linuxUser16",
          "uid":"1219059"
        },
"pos": [41.9757030, -87.6921867],
"address": {
          "housenumber": "5157",
          "postcode": "60625",
          "street": "North Lincoln Ave"
        },
"amenity": "restaurant",
"cuisine": "mexican",
"name": "La Cabana De Don Luis",
"phone": "1 (773)-271-5176"
}

You have to complete the function 'shape_element'.
We have provided a function that will parse the map file, and call the function with the element
as an argument. You should return a dictionary, containing the shaped data for that element.
We have also provided a way to save the data in a file, so that you could use
mongoimport later on to import the shaped data into MongoDB. 

Note that in this exercise we do not use the 'update street name' procedures
you worked on in the previous exercise. If you are using this code in your final
project, you are strongly encouraged to use the code from previous exercise to 
update the street names before you save them to JSON. 

In particular the following things should be done:
- you should process only 2 types of top level tags: "node" and "way"
- all attributes of "node" and "way" should be turned into regular key/value pairs, except:
    - attributes in the CREATED array should be added under a key "created"
    - attributes for latitude and longitude should be added to a "pos" array,
      for use in geospacial indexing. Make sure the values inside "pos" array are floats
      and not strings. 
- if second level tag "k" value contains problematic characters, it should be ignored
- if second level tag "k" value starts with "addr:", it should be added to a dictionary "address"
- if second level tag "k" value does not start with "addr:", but contains ":", you can process it
  same as any other tag.
- if there is a second ":" that separates the type/direction of a street,
  the tag should be ignored, for example:

<tag k="addr:housenumber" v="5158"/>
<tag k="addr:street" v="North Lincoln Avenue"/>
<tag k="addr:street:name" v="Lincoln"/>
<tag k="addr:street:prefix" v="North"/>
<tag k="addr:street:type" v="Avenue"/>
<tag k="amenity" v="pharmacy"/>

  should be turned into:

{...
"address": {
    "housenumber": 5158,
    "street": "North Lincoln Avenue"
}
"amenity": "pharmacy",
...
}

- for "way" specifically:

  <nd ref="305896090"/>
  <nd ref="1719825889"/>

should be turned into
"node_refs": ["305896090", "1719825889"]
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    print 11111
    print element
    print 22222
    node['created'] = {}
    node['address'] = {}
    node['node_refs'] = []
    node['pos'] = [0, 0]
    if element.tag == "node" or element.tag == "way" :
        # YOUR CODE HERE
        for tag in element.iter():
            print 22333
            print tag.attrib
            
            if tag.tag == 'tag': # if it is a secondary tag
                key = tag.get('k')
                if re.search(lower, key):
                    print 'lower', key, tag.get('v')
                    node[key] = tag.get('v')
                    print node
                elif re.search(lower_colon, key):
                    print 'lower colon', key, tag.get('v')
                    if key[0:4] == 'addr':
                        node['address'][key[5:]] = tag.get('v')
                    else:
                        node[key] = tag.get('v')
                    print node
                elif re.search(problemchars, key):
                    print 'problematic', key
                else:
                    print 'else', key
            
            else:
                node['type'] = element.tag

                for k, v in tag.attrib.iteritems():
                    if k in CREATED:
                        node['created'][k] = v

                    elif k == 'lat':
                        node['pos'][0] = float(v)

                    elif k == 'lon':
                        node['pos'][1] = float(v)

                    elif k == 'user':
                        pass

                    elif k == 'ref' and element.tag == 'way':
                        node['node_refs'].append(v)

                    else: 
                        node[k] = v

        print 33333
        print node
        print 44444
        if node['address'] == {}:
            del node['address']
            
        if len(node['node_refs']) == 0:
            del node['node_refs']
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

def test():
    # NOTE: if you are running this code on your computer, with a larger dataset, 
    # call the process_map procedure with pretty=False. The pretty=True option adds 
    # additional spaces to the output, making it significantly larger.
    data = process_map('example.osm', True)
    #pprint.pprint(data)
    
    print 'TEST'
    print data[0]
    
    correct_first_elem = {
        "id": "261114295", 
        "visible": "true", 
        "type": "node", 
        "pos": [41.9730791, -87.6866303], 
        "created": {
            "changeset": "11129782", 
            "user": "bbmiller", 
            "version": "7", 
            "uid": "451048", 
            "timestamp": "2012-03-28T18:31:23Z"
        }
    }
    assert data[0] == correct_first_elem
    
    print 'TEST'
    print data[-1]
    assert data[-1]["address"] == {
                                    "street": "West Lexington St.", 
                                    "housenumber": "1412"
                                      }
    assert data[-1]["node_refs"] == [ "2199822281", "2199822390",  "2199822392", "2199822369", 
                                    "2199822370", "2199822284", "2199822281"]

if __name__ == "__main__":
    test()
