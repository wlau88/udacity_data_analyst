# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
weather = pd.read_csv('turnstile_data_master_with_weather.csv')

# %%
weather.head()
# Out:
#    Unnamed: 0  UNIT       DATEn     TIMEn  Hour    DESCn  ENTRIESn_hourly  \
# 0           0  R001  2011-05-01  01:00:00     1  REGULAR                0
# 1           1  R001  2011-05-01  05:00:00     5  REGULAR              217
# 2           2  R001  2011-05-01  09:00:00     9  REGULAR              890
# 3           3  R001  2011-05-01  13:00:00    13  REGULAR             2451
# 4           4  R001  2011-05-01  17:00:00    17  REGULAR             4400
#
#    EXITSn_hourly  maxpressurei  maxdewpti   ...     meandewpti  meanpressurei  \
# 0              0         30.31         42   ...             39          30.27
# 1            553         30.31         42   ...             39          30.27
# 2           1262         30.31         42   ...             39          30.27
# 3           3708         30.31         42   ...             39          30.27
# 4           2501         30.31         42   ...             39          30.27
#
# ...

# %%
weather['rain'].mean()
# Out:
# 0.3342452880235845

# %%
weather['Hour'].unique()
# Out:
# array([ 1,  5,  9, 13, 17, 21,  0,  4, 12, 16, 20,  8,  2,  6, 10, 14, 18,
#        22,  3,  7, 11, 15, 19, 23])

# %%
weather.columns
# Out:
# Index([u'Unnamed: 0', u'UNIT', u'DATEn', u'TIMEn', u'Hour', u'DESCn', u'ENTRIESn_hourly', u'EXITSn_hourly', u'maxpressurei', u'maxdewpti', u'mindewpti', u'minpressurei', u'meandewpti', u'meanpressurei', u'fog', u'rain', u'meanwindspdi', u'mintempi', u'meantempi', u'maxtempi', u'precipi', u'thunder'], dtype='object')

# %%
ggplot(aes(x='Hour', y='ENTRIESn_hourly'), data=weather.groupby('Hour').mean().reset_index()) + geom_point(color='red') + geom_line(color='red')
# Out:
# <ggplot: (291911269)>

# %%
weather.groupby('UNIT').mean().reset_index()
# Out:
#      UNIT    Unnamed: 0       Hour  ENTRIESn_hourly  EXITSn_hourly  \
# 0    R001  63034.053763  11.086022      4030.548387    3809.881720
# 1    R002  63805.874317  11.049180       964.672131     856.918033
# 2    R003  62180.348837  10.156977       208.941860     147.284884
# 3    R004  63874.369318  10.113636       529.000000     401.886364
# 4    R005  64023.142857  10.188571       520.177143     407.308571
# 5    R006  64935.078947   9.963158       576.173684     403.994737
# 6    R007  64588.658824  10.117647       367.005882     299.800000
# 7    R008  63949.170732  10.213415       406.274390     330.310976
# 8    R009  64721.122093  10.063953       325.156977     266.744186
# 9    R010  63673.521978  12.016484      4693.642857    3951.989011
# 10   R011  63171.517766   9.903553      8035.096447    6500.883249
# 11   R012  60592.440191  10.081340      7486.851675    5446.933014
# 12   R013  64554.479167  10.010417      2491.994792    3871.911458
# ...

# %%
ggplot(aes(x='ENTRIESn_hourly'), data=weather.groupby('UNIT').mean().reset_index()) \
+ geom_histogram() + ylab('Frequency') + \
ggtitle('Histogram of ENTRIESn_hourly grouped by subway stations')
# Out:
# <ggplot: (318015117)>

# %%
ggplot(aes(x='UNIT', y='ENTRIESn_hourly'), data=weather.groupby('UNIT').mean().reset_index()) \
+ geom_point()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Warren/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     688                 type_pprinters=self.type_printers,
#     689                 deferred_pprinters=self.deferred_printers)
# --> 690             printer.pretty(obj)
#     691             printer.flush()
#     692             return stream.getvalue()
#
# /Users/Warren/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     405                             if callable(meth):
#     406                                 return meth(obj, self, cycle)
# --> 407             return _default_pprint(obj, self, cycle)
#     408         finally:
#     409             self.end_group()
#
# /Users/Warren/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
# ...

# %%
import numpy as np
import pandas
import statsmodels.api as sm

"""
In this question, you need to:
1) implement the linear_regression() procedure
2) Select features (in the predictions procedure) and make predictions.

"""

def linear_regression(features, values):
    """
    Perform linear regression given a data set with an arbitrary number of features.
    
    This can be the same code as in the lesson #3 exercise.
    """
    features_with_intercept = sm.add_constant(features)
    model = sm.OLS(values, features_with_intercept).fit()
    result = model.params
    intercept, params = result[0], result[1:]
    
    return intercept, params

def predictions(dataframe):
    '''
    The NYC turnstile data is stored in a pandas dataframe called weather_turnstile.
    Using the information stored in the dataframe, let's predict the ridership of
    the NYC subway using linear regression with gradient descent.
    
    You can download the complete turnstile weather dataframe here:
    https://www.dropbox.com/s/meyki2wl9xfa7yk/turnstile_data_master_with_weather.csv    
    
    Your prediction should have a R^2 value of 0.40 or better.
    You need to experiment using various input features contained in the dataframe. 
    We recommend that you don't use the EXITSn_hourly feature as an input to the 
    linear model because we cannot use it as a predictor: we cannot use exits 
    counts as a way to predict entry counts. 
    
    Note: Due to the memory and CPU limitation of our Amazon EC2 instance, we will
    give you a random subet (~10%) of the data contained in 
    turnstile_data_master_with_weather.csv. You are encouraged to experiment with 
    this exercise on your own computer, locally. If you do, you may want to complete Exercise
    8 using gradient descent, or limit your number of features to 10 or so, since ordinary
    least squares can be very slow for a large number of features.
    
    If you receive a "server has encountered an error" message, that means you are 
    hitting the 30-second limit that's placed on running your program. Try using a
    smaller number of features.
    '''
    ################################ MODIFY THIS SECTION #####################################
    # Select features. You should modify this section to try different features!             #
    # We've selected rain, precipi, Hour, meantempi, and UNIT (as a dummy) to start you off. #
    # See this page for more info about dummy variables:                                     #
    # http://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html          #
    ##########################################################################################
    features = dataframe[['rain', 'precipi', 'Hour', 'meantempi']]
    dummy_units = pandas.get_dummies(dataframe['UNIT'], prefix='unit')
    features = features.join(dummy_units)
    
    # Values
    values = dataframe['ENTRIESn_hourly']

    # Perform linear regression
    intercept, params = linear_regression(features, values)
    
    predictions = intercept + np.dot(features, params)
    return predictions

# %%
from datetime import datetime

# %%
datetime.strptime(weather['DATEn'][0], '%Y-%m-%d').weekday()
# Out:
# 6

# %%
datetime.strftime()

# %%
weather['DATEn'].unique()
# Out:
# array(['2011-05-01', '2011-05-02', '2011-05-03', '2011-05-04',
#        '2011-05-05', '2011-05-06', '2011-05-07', '2011-05-08',
#        '2011-05-09', '2011-05-10', '2011-05-11', '2011-05-12',
#        '2011-05-13', '2011-05-14', '2011-05-15', '2011-05-16',
#        '2011-05-17', '2011-05-18', '2011-05-19', '2011-05-20',
#        '2011-05-21', '2011-05-22', '2011-05-23', '2011-05-24',
#        '2011-05-25', '2011-05-26', '2011-05-27', '2011-05-28',
#        '2011-05-29', '2011-05-30'], dtype=object)

# %%
weather.head()
# Out:
#    Unnamed: 0  UNIT       DATEn     TIMEn  Hour    DESCn  ENTRIESn_hourly  \
# 0           0  R001  2011-05-01  01:00:00     1  REGULAR                0
# 1           1  R001  2011-05-01  05:00:00     5  REGULAR              217
# 2           2  R001  2011-05-01  09:00:00     9  REGULAR              890
# 3           3  R001  2011-05-01  13:00:00    13  REGULAR             2451
# 4           4  R001  2011-05-01  17:00:00    17  REGULAR             4400
#
#    EXITSn_hourly  maxpressurei  maxdewpti   ...     meandewpti  meanpressurei  \
# 0              0         30.31         42   ...             39          30.27
# 1            553         30.31         42   ...             39          30.27
# 2           1262         30.31         42   ...             39          30.27
# 3           3708         30.31         42   ...             39          30.27
# 4           2501         30.31         42   ...             39          30.27
#
# ...

# %%
weather.groupby('precipi').mean().reset_index()['ENTRIESn_hourly']
# Out:
# 0    1090.278780
# 1    1066.387753
# 2    1200.274838
# 3    1208.266192
# 4    1327.224794
# 5     611.844828
# 6    1315.695897
# 7    1285.095195
# 8     619.756751
# 9    1337.444368
# Name: ENTRIESn_hourly, dtype: float64

# %%
weather.groupby('precipi').mean().reset_index()['precipi']
# Out:
# 0    0.00
# 1    0.07
# 2    0.10
# 3    0.17
# 4    0.24
# 5    0.29
# 6    0.50
# 7    0.67
# 8    0.89
# 9    2.18
# Name: precipi, dtype: float64

# %%
ggplot(aes(x='precipi', y='ENTRIESn_hourly'), data=weather.groupby('precipi').mean().reset_index()) + geom_bar(stat='bar')
# Out:
# <ggplot: (314011541)>

# %%
weather[weather['rain'] == 1]['ENTRIESn_hourly'].hist(alpha=0.5)
weather[weather['rain'] == 0]['ENTRIESn_hourly'].hist(alpha=0.5)

# %%
weather['meantempi'].unique()
# Out:
# array([ 60.,  57.,  65.,  55.,  56.,  61.,  64.,  63.,  62.,  58.,  68.,
#         67.,  74.,  75.,  71.,  76.,  78.])

# %%
weather.groupby('meantempi')['ENTRIESn_hourly'].boxplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-dceef3df3153> in <module>()
# ----> 1 weather.groupby('meantempi')['ENTRIESn_hourly'].boxplot()
#
# /Users/Warren/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     509
#     510         raise AttributeError("%r object has no attribute %r" %
# --> 511                              (type(self).__name__, attr))
#     512
#     513     def __getitem__(self, key):
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'boxplot'

# %%
weather[weather['maxpressurei'] == 1]['ENTRIESn_hourly'].hist(alpha=0.5)
weather[weather['maxpressurei'] == 0]['ENTRIESn_hourly'].hist(alpha=0.5)

# %%
weather[weather['fog'] == 1]['ENTRIESn_hourly'].hist(alpha=0.5, bins=20)
weather[weather['fog'] == 0]['ENTRIESn_hourly'].hist(alpha=0.5, bins=20)

# %%
weather[weather['meanwindspdi'] == 1]['ENTRIESn_hourly'].hist(alpha=0.5, bins=20)
weather[weather['meanwindspdi'] == 0]['ENTRIESn_hourly'].hist(alpha=0.5, bins=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-d28100e00ff8> in <module>()
#       1 weather[weather['meanwindspdi'] == 1]['ENTRIESn_hourly'].hist(alpha=0.5, bins=20)
# ----> 2 weather[weather['meanwindspdi'] == 0]['ENTRIESn_hourly'].hist(alpha=0.5, bins=20)
#
# /Users/Warren/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2817         values = self.dropna().values
#    2818
# -> 2819         ax.hist(values, bins=bins, **kwds)
#    2820         ax.grid(grid)
#    2821         axes = np.array([ax])
#
# /Users/Warren/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
# ...

# %%
weather['meanwindspdi'].hist()

# %%
plt.plot(weather['precipi'], weather['ENTRIESn_hourly'], 'bo', alpha=0.5)

# %%
plt.plot(weather['Hour'], weather['ENTRIESn_hourly'], 'bo', alpha=0.5)

# %% [markdown]
# ###Improved weather data

# %%
improved_weather = pd.read_csv('improved-dataset/turnstile_weather_v2.csv')

# %%
improved_weather.columns
# Out:
# Index([u'UNIT', u'DATEn', u'TIMEn', u'ENTRIESn', u'EXITSn', u'ENTRIESn_hourly', u'EXITSn_hourly', u'datetime', u'hour', u'day_week', u'weekday', u'station', u'latitude', u'longitude', u'conds', u'fog', u'precipi', u'pressurei', u'rain', u'tempi', u'wspdi', u'meanprecipi', u'meanpressurei', u'meantempi', u'meanwspdi', u'weather_lat', u'weather_lon'], dtype='object')

# %%
improved_weather.head()
# Out:
#    UNIT     DATEn     TIMEn  ENTRIESn   EXITSn  ENTRIESn_hourly  \
# 0  R003  05-01-11  00:00:00   4388333  2911002                0
# 1  R003  05-01-11  04:00:00   4388333  2911002                0
# 2  R003  05-01-11  12:00:00   4388333  2911002                0
# 3  R003  05-01-11  16:00:00   4388333  2911002                0
# 4  R003  05-01-11  20:00:00   4388333  2911002                0
#
#    EXITSn_hourly             datetime  hour  day_week     ...       pressurei  \
# 0              0  2011-05-01 00:00:00     0         6     ...           30.22
# 1              0  2011-05-01 04:00:00     4         6     ...           30.25
# 2              0  2011-05-01 12:00:00    12         6     ...           30.28
# 3              0  2011-05-01 16:00:00    16         6     ...           30.26
# 4              0  2011-05-01 20:00:00    20         6     ...           30.28
#
#   rain  tempi  wspdi meanprecipi  meanpressurei  meantempi  meanwspdi  \
# ...

# %%
improved_weather['station'].head()
# Out:
# 0    CYPRESS HILLS
# 1    CYPRESS HILLS
# 2    CYPRESS HILLS
# 3    CYPRESS HILLS
# 4    CYPRESS HILLS
# Name: station, dtype: object

# %%
improved_weather['conds'].head()
# Out:
# 0            Clear
# 1    Partly Cloudy
# 2    Mostly Cloudy
# 3    Mostly Cloudy
# 4    Mostly Cloudy
# Name: conds, dtype: object

# %%
import numpy as np
import pandas
import statsmodels.api as sm

"""
In this question, you need to:
1) implement the linear_regression() procedure
2) Select features (in the predictions procedure) and make predictions.

"""

def linear_regression(features, values):
    """
    Perform linear regression given a data set with an arbitrary number of features.
    
    This can be the same code as in the lesson #3 exercise.
    """
    features_with_intercept = sm.add_constant(features)
    model = sm.OLS(values, features_with_intercept).fit()
    result = model.params
    intercept, params = result[0], result[1:]
    
    print model.summary()
    
    return intercept, params

def predictions(dataframe):
    '''
    The NYC turnstile data is stored in a pandas dataframe called weather_turnstile.
    Using the information stored in the dataframe, let's predict the ridership of
    the NYC subway using linear regression with gradient descent.
    
    You can download the complete turnstile weather dataframe here:
    https://www.dropbox.com/s/meyki2wl9xfa7yk/turnstile_data_master_with_weather.csv    
    
    Your prediction should have a R^2 value of 0.40 or better.
    You need to experiment using various input features contained in the dataframe. 
    We recommend that you don't use the EXITSn_hourly feature as an input to the 
    linear model because we cannot use it as a predictor: we cannot use exits 
    counts as a way to predict entry counts. 
    
    Note: Due to the memory and CPU limitation of our Amazon EC2 instance, we will
    give you a random subet (~10%) of the data contained in 
    turnstile_data_master_with_weather.csv. You are encouraged to experiment with 
    this exercise on your own computer, locally. If you do, you may want to complete Exercise
    8 using gradient descent, or limit your number of features to 10 or so, since ordinary
    least squares can be very slow for a large number of features.
    
    If you receive a "server has encountered an error" message, that means you are 
    hitting the 30-second limit that's placed on running your program. Try using a
    smaller number of features.
    '''
    ################################ MODIFY THIS SECTION #####################################
    # Select features. You should modify this section to try different features!             #
    # We've selected rain, precipi, Hour, meantempi, and UNIT (as a dummy) to start you off. #
    # See this page for more info about dummy variables:                                     #
    # http://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html          #
    ##########################################################################################
    features = dataframe[['rain', 'fog', 'precipi', 'meantempi']]
    dummy_units = pandas.get_dummies(dataframe['UNIT'], prefix='unit')
    features = features.join(dummy_units)
    dummy_day_week = pandas.get_dummies(dataframe['day_week'], prefix='day_week')
    features = features.join(dummy_day_week)
    dummy_weekday = pandas.get_dummies(dataframe['weekday'], prefix='weekday')
    features = features.join(dummy_weekday)
    dummy_station = pandas.get_dummies(dataframe['station'], prefix='station')
    features = features.join(dummy_station)
    dummy_conds = pandas.get_dummies(dataframe['conds'], prefix='conds')
    features = features.join(dummy_conds)
    dummy_conds = pandas.get_dummies(dataframe['hour'], prefix='hour')
    features = features.join(dummy_conds)
    
    print 'size of features matrix: ', features.shape
    
    # Values
    values = dataframe['ENTRIESn_hourly']

    # Perform linear regression
    intercept, params = linear_regression(features, values)
    
    predictions = intercept + np.dot(features, params)
    return predictions

# %% [markdown]
# UNIT', u'DATEn', u'TIMEn', u'ENTRIESn', u'EXITSn', u'ENTRIESn_hourly', u'EXITSn_hourly', u'datetime', u'hour', u'day_week', u'weekday', u'station', u'latitude', u'longitude', u'conds', u'fog', u'precipi', u'pressurei', u'rain', u'tempi', u'wspdi', u'meanprecipi', u'meanpressurei', u'meantempi', u'meanwspdi', u'weather_lat', u'weather_lon'

# %%
predictions(improved_weather)
# Out:
# size of features matrix:  (42649, 478)
#                             OLS Regression Results
# ...
# Dep. Variable:        ENTRIESn_hourly   R-squared:                       0.548
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                     193.7
# Date:                Sun, 01 Nov 2015   Prob (F-statistic):               0.00
# Time:                        10:40:00   Log-Likelihood:            -3.8437e+05
# No. Observations:               42649   AIC:                         7.693e+05
# Df Residuals:                   42383   BIC:                         7.716e+05
# Df Model:                         265
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# ...

# %%
from ggplot import *

# %%
ls
# Out:
# improved-dataset/                       turnstile-weather-variables.pdf
# improved-dataset.zip                    turnstile_data_master_with_weather.csv
# p2_scratchpad.ipynb

# %%
ls ../
# Out:
# intro_to_ds/        p1_stroop_effect/   p2_nyc_subway_data/

# %%
hr = pd.read_csv('../intro_to_ds/hr_year.csv')

# %%
hr.head(10)
# Out:
#    Unnamed: 0  yearID  HR
# 0           1    1871  47
# 1           2    1872  35
# 2           3    1873  46
# 3           4    1874  40
# 4           5    1875  40
# 5           6    1876  40
# 6           7    1877  24
# 7           8    1878  23
# 8           9    1879  58
# 9          10    1880  62

# %%
ggplot(aes(x='yearID', y='HR'), data=hr) + \
geom_point(color='red') + geom_line(color='red')
# Out:
# <ggplot: (284716529)>

# %%
hr = pd.read_csv('../intro_to_ds/hr_by_team_year_sf_la.csv')

# %%
hr.head(10)
# Out:
#    Unnamed: 0 teamID  yearID   HR
# 0        1320    LAN    1958  172
# 1        1325    SFN    1958  170
# 2        1336    LAN    1959  148
# 3        1341    SFN    1959  167
# 4        1352    LAN    1960  126
# 5        1357    SFN    1960  130
# 6        1369    LAN    1961  157
# 7        1375    SFN    1961  183
# 8        1388    LAN    1962  140
# 9        1395    SFN    1962  204
